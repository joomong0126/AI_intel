# %% [markdown]
# # 타이타닉을 주제로 살았다 죽었다른 맞추겠다_ 이진분류기

# %%
import seaborn as sns
import pandas as pd # pandas 패키지를 사용
import numpy as np

# %%
raw_data = sns.load_dataset('titanic')
raw_data

# %% [markdown]
# pandas
